# %% [markdown]
# <a href="https://colab.research.google.com/github/KArimCHidekh/Classifying-Handwritten-Digits-Using-A-Multilayer-Perceptron-Classifier-MLP-/blob/main/models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

#---------------------------------------------------------
# Architecture réseau : MLP (784,900,256,128,10)
# Nb itérations       : 20
# Fct activation      : relu, relu, relu , softmax
# Mesure erreurs      : categorical_crossentropy
# Algo apprentissage  : RmsProp
# Utilisation dropout : non
# Autre               : RAS
#---------------------------------------------------------
# Taux apprentissage  : ~99,56 %
# taux validation     : ~98.42 %
#---------------------------------------------------------
# Importation des modules TensorFlow & Keras
#  => construction et exploitation de réseaux de neurones
import tensorflow as tf

# Importation du module numpy
#  => manipulation de tableaux multidimensionnels
import numpy as np

# Importation du module graphique
#  => tracé de courbes et diagrammes
import matplotlib.pyplot as plt

#----------------------------------------------------------------------------
# Chargement des données d'apprentissage et de tests
#----------------------------------------------------------------------------
# Chargement en mémoire de la base de données des caractères MNIST
#  => tableaux de type ndarray (Numpy) avec des valeur entières
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

#----------------------------------------------------------------------------
# Changements de format pour exploitation
#----------------------------------------------------------------------------
# les valeurs associées aux pixels sont des entiers entre 0 et 255
#  => transformation en valeurs réelles entre 0.0 et 1.0
x_train, x_test = x_train / 255.0, x_test / 255.0
# Les données en entrée sont des matrices de pixels 28x28
#  => transformation en vecteurs de 28x28=784 pixels
x_train = x_train.reshape(60000, 784)
x_test  = x_test.reshape(10000, 784)
# Les données de sortie sont des entiers associés aux chiffres à identifier
#  => transformation en vecteurs booléens pour une classification en 10 valeurs
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test  = tf.keras.utils.to_categorical(y_test, 10)


#----------------------------------------------------------------------------
# DESCRIPTION du modèle Perceptron multicouches (MLP)
#  => 3 couches cachées avec 900, 256, et 128 neurones respectivement
#----------------------------------------------------------------------------
# Création d'un réseau multicouches
model = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(784,)),
  tf.keras.layers.Dense(900, activation='relu'),
  tf.keras.layers.Dropout(0.15),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.15),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.15),
  tf.keras.layers.Dense(10, activation='softmax')
])

#----------------------------------------------------------------------------
# COMPILATION du réseau 
#  => configuration de la procédure pour l'apprentissage
#----------------------------------------------------------------------------
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
#model.fit(x_train, y_train, epochs=10, batch_size=128)



history = model.fit(x_train, y_train, epochs=20, batch_size=58,
                    validation_data=(x_test, y_test))
model.evaluate(x_test,  y_test, verbose=2)

# Evaluating the model on test dataset
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc:.2%}')

# Plotting the training and validation accuracy over epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
#----------------------------------------------------------------------------
# Out:
# Epoch 1/20
# 1035/1035 [==============================] - 6s 5ms/step - loss: 0.2414 - accuracy: 0.9269 - val_loss: 0.1053 - val_accuracy: 0.9697
# Epoch 2/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.1091 - accuracy: 0.9686 - val_loss: 0.0901 - val_accuracy: 0.9736
# Epoch 3/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0867 - accuracy: 0.9756 - val_loss: 0.0833 - val_accuracy: 0.9766
# Epoch 4/20
# 1035/1035 [==============================] - 5s 5ms/step - loss: 0.0721 - accuracy: 0.9801 - val_loss: 0.0827 - val_accuracy: 0.9792
# Epoch 5/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0590 - accuracy: 0.9837 - val_loss: 0.1019 - val_accuracy: 0.9773
# Epoch 6/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0525 - accuracy: 0.9865 - val_loss: 0.0792 - val_accuracy: 0.9833
# Epoch 7/20
# 1035/1035 [==============================] - 5s 5ms/step - loss: 0.0492 - accuracy: 0.9875 - val_loss: 0.0951 - val_accuracy: 0.9795
# Epoch 8/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0458 - accuracy: 0.9883 - val_loss: 0.0827 - val_accuracy: 0.9827
# Epoch 9/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0410 - accuracy: 0.9897 - val_loss: 0.1294 - val_accuracy: 0.9756
# Epoch 10/20
# 1035/1035 [==============================] - 5s 4ms/step - loss: 0.0384 - accuracy: 0.9911 - val_loss: 0.1058 - val_accuracy: 0.9822
# Epoch 11/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0355 - accuracy: 0.9913 - val_loss: 0.0999 - val_accuracy: 0.9827
# Epoch 12/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0306 - accuracy: 0.9926 - val_loss: 0.1033 - val_accuracy: 0.9838
# Epoch 13/20
# 1035/1035 [==============================] - 5s 4ms/step - loss: 0.0316 - accuracy: 0.9919 - val_loss: 0.1157 - val_accuracy: 0.9830
# Epoch 14/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0263 - accuracy: 0.9936 - val_loss: 0.1131 - val_accuracy: 0.9836
# Epoch 15/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0276 - accuracy: 0.9932 - val_loss: 0.1351 - val_accuracy: 0.9823
# Epoch 16/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0241 - accuracy: 0.9942 - val_loss: 0.1249 - val_accuracy: 0.9837
# Epoch 17/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0189 - accuracy: 0.9954 - val_loss: 0.1271 - val_accuracy: 0.9838
# Epoch 18/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0203 - accuracy: 0.9950 - val_loss: 0.1210 - val_accuracy: 0.9847
# Epoch 19/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0194 - accuracy: 0.9953 - val_loss: 0.1284 - val_accuracy: 0.9853
# Epoch 20/20
# 1035/1035 [==============================] - 4s 4ms/step - loss: 0.0182 - accuracy: 0.9956 - val_loss: 0.1291 - val_accuracy: 0.9842
# 313/313 - 1s - loss: 0.1291 - accuracy: 0.9842 - 593ms/epoch - 2ms/step
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1291 - accuracy: 0.9842
# Test accuracy: 98.42%

# %%
# -*- coding: utf-8 -*-

#---------------------------------------------------------
# Architecture réseau : MLP (784,1024,512,256,128,10)
# Nb itérations       : 40
# Fct activation      : relu, relu, relu, relu , softmax
# Mesure erreurs      : categorical_crossentropy
# Algo apprentissage  : adam
# Utilisation dropout : non
# Autre               : RAS
#---------------------------------------------------------
# Taux apprentissage  : ~99,44 %
# taux validation     : ~98.7 %
#---------------------------------------------------------

#############################################################################
#               FONCTIONNEMENT DE BASE DU RESEAU                            #
#############################################################################

# Importation des modules TensorFlow & Keras
#  => construction et exploitation de réseaux de neurones
import tensorflow as tf

# Importation du module numpy
#  => manipulation de tableaux multidimensionnels
import numpy as np

# Importation du module graphique
#  => tracé de courbes et diagrammes
import matplotlib.pyplot as plt

#----------------------------------------------------------------------------
# Chargement des données d'apprentissage et de tests
#----------------------------------------------------------------------------
# Chargement en mémoire de la base de données des caractères MNIST
#  => tableaux de type ndarray (Numpy) avec des valeur entières
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

#----------------------------------------------------------------------------
# Changements de format pour exploitation
#----------------------------------------------------------------------------
# les valeurs associées aux pixels sont des entiers entre 0 et 255
#  => transformation en valeurs réelles entre 0.0 et 1.0
x_train, x_test = x_train / 255.0, x_test / 255.0
# Les données en entrée sont des matrices de pixels 28x28
#  => transformation en vecteurs de 28x28=784 pixels
x_train = x_train.reshape(60000, 784)
x_test  = x_test.reshape(10000, 784)
# Les données de sortie sont des entiers associés aux chiffres à identifier
#  => transformation en vecteurs booléens pour une classification en 10 valeurs
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test  = tf.keras.utils.to_categorical(y_test, 10)


#----------------------------------------------------------------------------
# DESCRIPTION du modèle Perceptron multicouches (MLP)
#  => 3 couches cachées avec 900, 256, et 128 neurones respectivement
#----------------------------------------------------------------------------
# Création d'un réseau multicouches
model = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(784,)),
  tf.keras.layers.Dense(1024, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(10, activation='softmax')
])

#----------------------------------------------------------------------------
# COMPILATION du réseau 
#  => configuration de la procédure pour l'apprentissage
#----------------------------------------------------------------------------


opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=40, batch_size=128,
                    validation_data=(x_test, y_test))
model.evaluate(x_test,  y_test, verbose=2)

# Evaluating the model on test dataset
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc:.2%}')

# Plotting the training and validation accuracy over epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
#----------------------------------------------------------------------------
# Out:
# Epoch 1/40
# 469/469 [==============================] - 8s 8ms/step - loss: 0.3014 - accuracy: 0.9085 - val_loss: 0.1125 - val_accuracy: 0.9655
# Epoch 2/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1397 - accuracy: 0.9578 - val_loss: 0.0942 - val_accuracy: 0.9712
# Epoch 3/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1084 - accuracy: 0.9677 - val_loss: 0.0849 - val_accuracy: 0.9738
# Epoch 4/40
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0930 - accuracy: 0.9721 - val_loss: 0.0736 - val_accuracy: 0.9772
# Epoch 5/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0807 - accuracy: 0.9753 - val_loss: 0.0744 - val_accuracy: 0.9769
# Epoch 6/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0679 - accuracy: 0.9787 - val_loss: 0.0713 - val_accuracy: 0.9800
# Epoch 7/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0658 - accuracy: 0.9790 - val_loss: 0.0779 - val_accuracy: 0.9763
# Epoch 8/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0595 - accuracy: 0.9811 - val_loss: 0.0673 - val_accuracy: 0.9813
# Epoch 9/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0535 - accuracy: 0.9831 - val_loss: 0.0710 - val_accuracy: 0.9806
# Epoch 10/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0511 - accuracy: 0.9838 - val_loss: 0.0650 - val_accuracy: 0.9813
# Epoch 11/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0468 - accuracy: 0.9852 - val_loss: 0.0583 - val_accuracy: 0.9827
# Epoch 12/40
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0440 - accuracy: 0.9859 - val_loss: 0.0608 - val_accuracy: 0.9822
# Epoch 13/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0430 - accuracy: 0.9862 - val_loss: 0.0608 - val_accuracy: 0.9818
# Epoch 14/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 0.0623 - val_accuracy: 0.9846
# Epoch 15/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0381 - accuracy: 0.9880 - val_loss: 0.0661 - val_accuracy: 0.9824
# Epoch 16/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0393 - accuracy: 0.9877 - val_loss: 0.0621 - val_accuracy: 0.9830
# Epoch 17/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0334 - accuracy: 0.9896 - val_loss: 0.0591 - val_accuracy: 0.9842
# Epoch 18/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0338 - accuracy: 0.9891 - val_loss: 0.0627 - val_accuracy: 0.9832
# Epoch 19/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0320 - accuracy: 0.9893 - val_loss: 0.0658 - val_accuracy: 0.9821
# Epoch 20/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0296 - accuracy: 0.9904 - val_loss: 0.0627 - val_accuracy: 0.9842
# Epoch 21/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0286 - accuracy: 0.9908 - val_loss: 0.0575 - val_accuracy: 0.9854
# Epoch 22/40
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0245 - accuracy: 0.9924 - val_loss: 0.0649 - val_accuracy: 0.9840
# Epoch 23/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0266 - accuracy: 0.9915 - val_loss: 0.0629 - val_accuracy: 0.9839
# Epoch 24/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0235 - accuracy: 0.9926 - val_loss: 0.0711 - val_accuracy: 0.9823
# Epoch 25/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.0583 - val_accuracy: 0.9851
# Epoch 26/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0231 - accuracy: 0.9928 - val_loss: 0.0589 - val_accuracy: 0.9854
# Epoch 27/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0239 - accuracy: 0.9922 - val_loss: 0.0674 - val_accuracy: 0.9823
# Epoch 28/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0209 - accuracy: 0.9933 - val_loss: 0.0590 - val_accuracy: 0.9853
# Epoch 29/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0196 - accuracy: 0.9938 - val_loss: 0.0621 - val_accuracy: 0.9848
# Epoch 30/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0207 - accuracy: 0.9931 - val_loss: 0.0514 - val_accuracy: 0.9858
# Epoch 31/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.0588 - val_accuracy: 0.9852
# Epoch 32/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0198 - accuracy: 0.9935 - val_loss: 0.0581 - val_accuracy: 0.9858
# Epoch 33/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0177 - accuracy: 0.9941 - val_loss: 0.0547 - val_accuracy: 0.9869
# Epoch 34/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0590 - val_accuracy: 0.9855
# Epoch 35/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.0607 - val_accuracy: 0.9865
# Epoch 36/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0584 - val_accuracy: 0.9846
# Epoch 37/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.0559 - val_accuracy: 0.9863
# Epoch 38/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0562 - val_accuracy: 0.9870
# Epoch 39/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.0590 - val_accuracy: 0.9861
# Epoch 40/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0183 - accuracy: 0.9944 - val_loss: 0.0581 - val_accuracy: 0.9870
# 313/313 - 1s - loss: 0.0581 - accuracy: 0.9870 - 715ms/epoch - 2ms/step
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0581 - accuracy: 0.9870
# Test accuracy: 98.70%
